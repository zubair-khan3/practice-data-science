# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("india.csv")
df
# Out:
#           Day    City Temperature  Wind    Event
# 0  01-01-2017  Indore          30   6.0     rain
# 1  02-01-2017  Indore          32   7.0    sunny
# 2  03-01-2017  Indore         NaN   NaN     cold
# 3  04-01-2017  Bhopal          34   6.0     rain
# 4  05-01-2017  Bhopal         NaN   8.0    sunny
# 5  06-01-2017   Dewas          31   4.0  thunder
# 6  07-01-2017   Dewas          29   NaN     dark
# 7  08-01-2017  Mumbai         NaN   2.0     rain
# 8  09-01-2017  Mumbai          36   6.0  thunder
# 9  10-01-2017  Mumbai               NaN    sunny

# %%
df = df.interpolate()
df
# Out:
#           Day    City Temperature  Wind    Event
# 0  01-01-2017  Indore          30   6.0     rain
# 1  02-01-2017  Indore          32   7.0    sunny
# 2  03-01-2017  Indore         NaN   6.5     cold
# 3  04-01-2017  Bhopal          34   6.0     rain
# 4  05-01-2017  Bhopal         NaN   8.0    sunny
# 5  06-01-2017   Dewas          31   4.0  thunder
# 6  07-01-2017   Dewas          29   3.0     dark
# 7  08-01-2017  Mumbai         NaN   2.0     rain
# 8  09-01-2017  Mumbai          36   6.0  thunder
# 9  10-01-2017  Mumbai               6.0    sunny

# %%
us = pd.read_csv('US.csv')
us
# Out:
#           Day      City Temperature  Wind    Event
# 0  01-01-2017  New york          30   6.0     rain
# 1  02-01-2017  New york          32   7.0    sunny
# 2  03-01-2017  New york         NaN   NaN     cold
# 3  04-01-2017      Cali          34   6.0     rain
# 4  05-01-2017      Cali         NaN   8.0    sunny
# 5  06-01-2017      Cali          31   4.0  thunder
# 6  07-01-2017      Cali          29   NaN     dark
# 7  08-01-2017    Texas          NaN   2.0     rain
# 8  09-01-2017    Texas           36   6.0  thunder
# 9  10-01-2017    Texas                NaN    sunny
